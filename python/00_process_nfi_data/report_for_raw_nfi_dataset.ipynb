# %%
from ydata_profiling import ProfileReport
import pandas as pd

# %%
raw = pd.read_csv(
    "20231201-103525_nfi_dataset_raw copy.csv",
    index_col=[0],
    low_memory=False,
)

# %%
display(raw.head(10))
display(raw.describe())
display(raw.info(verbose=True))
# Out:
#     idp  site_total_ba_at_v1  site_total_ba_at_v2  site_ba_prc_dead_at_v1  \
# 1    23             9.108369             9.443877                     0.0
# 2    23             9.108369             9.443877                     0.0
# 3    23             9.108369             9.443877                     0.0
# 4    23             9.108369             9.443877                     0.0
# 5    23             9.108369             9.443877                     0.0
# 6    23             9.108369             9.443877                     0.0
# 7    23             9.108369             9.443877                     0.0
# 8    23             9.108369             9.443877                     0.0
# 9    23             9.108369             9.443877                     0.0
# 10   41            37.635146            37.955904                     0.0
#
#     site_ba_prc_dead_at_v2  site_ba_prc_cut_at_v2  site_ba_prc_rec_at_v2  \
# 1                 0.000000               0.108795               0.891205
# 2                 0.000000               0.108795               0.891205
# 3                 0.000000               0.108795               0.891205
# 4                 0.000000               0.108795               0.891205
# 5                 0.000000               0.108795               0.891205
# 6                 0.000000               0.108795               0.891205
# 7                 0.000000               0.108795               0.891205
# 8                 0.000000               0.108795               0.891205
# 9                 0.000000               0.108795               0.891205
# 10                0.012453               0.904859               0.082689
#
#     n_species_nfi  top1_species  top1_species_ba_1_mean  ...  obsriv2  typriv  \
# 1             2.0           2.0                1.304693  ...      NaN     NaN
# 2             2.0           2.0                1.304693  ...      NaN     NaN
# 3             2.0           2.0                1.304693  ...      NaN     NaN
# 4             2.0           2.0                1.304693  ...      NaN     NaN
# 5             2.0           2.0                1.304693  ...      NaN     NaN
# 6             2.0           2.0                1.304693  ...      NaN     NaN
# 7             2.0           2.0                1.304693  ...      NaN     NaN
# 8             2.0           2.0                1.304693  ...      NaN     NaN
# 9             2.0           2.0                1.304693  ...      NaN     NaN
# 10            2.0          54.0                6.037121  ...      NaN     NaN
#
#     distriv  denivriv  lign2  lign1  herb  mousse  obsveget obsdate
# 1       NaN       NaN    9.0    3.0   4.0     NaN       NaN     NaN
# 2       NaN       NaN    9.0    3.0   4.0     NaN       NaN     NaN
# 3       NaN       NaN    9.0    3.0   4.0     NaN       NaN     NaN
# 4       NaN       NaN    9.0    3.0   4.0     NaN       NaN     NaN
# 5       NaN       NaN    9.0    3.0   4.0     NaN       NaN     NaN
# 6       NaN       NaN    9.0    3.0   4.0     NaN       NaN     NaN
# 7       NaN       NaN    9.0    3.0   4.0     NaN       NaN     NaN
# 8       NaN       NaN    9.0    3.0   4.0     NaN       NaN     NaN
# 9       NaN       NaN    9.0    3.0   4.0     NaN       NaN     NaN
# 10      NaN       NaN    8.0    6.0   3.0     NaN       NaN     NaN
#
# [10 rows x 272 columns]
#                 idp  site_total_ba_at_v1  site_total_ba_at_v2  \
# count  1.318400e+06        622998.000000        622998.000000
# mean   8.154183e+05            50.634765            52.152796
# std    4.735046e+05            39.351285            39.684644
# min    1.900000e+01             0.233444             0.000000
# 25%    4.278580e+05            20.886349            21.960759
# 50%    8.049150e+05            41.326479            42.780811
# 75%    1.211065e+06            70.703948            72.528540
# max    1.654936e+06           459.173419           476.582429
#
#        site_ba_prc_dead_at_v1  site_ba_prc_dead_at_v2  site_ba_prc_cut_at_v2  \
# count           622998.000000           620883.000000          620883.000000
# mean                 0.035114                0.023272               0.072816
# std                  0.085465                0.067564               0.197078
# min                  0.000000                0.000000               0.000000
# 25%                  0.000000                0.000000               0.000000
# 50%                  0.000000                0.000000               0.000000
# 75%                  0.030717                0.015227               0.000000
# max                  1.000000                1.000000               1.000000
#
#        site_ba_prc_rec_at_v2  n_species_nfi   top1_species  \
# count          620883.000000  622998.000000  622998.000000
# mean                0.903912       2.943679      23.971807
# std                 0.202528       1.460316      24.001949
# min                 0.000000       1.000000       2.000000
# 25%                 0.913066       2.000000       3.000000
# 50%                 0.992052       3.000000      10.000000
# 75%                 1.000000       4.000000      52.000000
# max                 1.000000      11.000000     332.000000
#
#        top1_species_ba_1_mean  ...       obsriv2        typriv        distriv  \
# count           622998.000000  ...  37805.000000  54614.000000  393965.000000
# mean                 5.132418  ...      3.537654      3.633720       0.423236
# std                  5.153117  ...      1.243921      1.179564       0.868871
# min                  0.013332  ...      1.000000      1.000000       0.000000
# 25%                  1.500486  ...      3.000000      4.000000       0.000000
# 50%                  3.791799  ...      4.000000      4.000000       0.000000
# 75%                  7.222940  ...      4.000000      4.000000       0.000000
# max                151.475980  ...      6.000000      6.000000       3.000000
#
#            denivriv         lign2         lign1          herb         mousse  \
# count  92396.000000  1.303471e+06  1.303471e+06  1.303576e+06  924912.000000
# mean       0.240616  9.073711e+00  5.218869e+00  4.561790e+00       1.672952
# std        0.577840  1.473559e+00  3.090044e+00  3.144284e+00       2.353896
# min        0.000000  0.000000e+00  0.000000e+00  0.000000e+00       0.000000
# 25%        0.000000  9.000000e+00  3.000000e+00  2.000000e+00       0.000000
# 50%        0.000000  1.000000e+01  5.000000e+00  4.000000e+00       1.000000
# 75%        0.000000  1.000000e+01  8.000000e+00  7.000000e+00       2.000000
# max        2.000000  1.000000e+01  1.000000e+01  1.000000e+01      10.000000
#
#             obsveget        obsdate
# count  437944.000000  386744.000000
# mean        0.966320       0.119661
# std         1.816907       0.381374
# min         0.000000       0.000000
# 25%         0.000000       0.000000
# 50%         0.000000       0.000000
# 75%         1.000000       0.000000
# max         6.000000       3.000000
#
# [8 rows x 206 columns]
# <class 'pandas.core.frame.DataFrame'>
# Index: 1318400 entries, 1 to 1318400
# Data columns (total 272 columns):
#  #    Column                          Dtype
# ---   ------                          -----
#  0    idp                             int64
#  1    site_total_ba_at_v1             float64
#  2    site_total_ba_at_v2             float64
#  3    site_ba_prc_dead_at_v1          float64
#  4    site_ba_prc_dead_at_v2          float64
#  5    site_ba_prc_cut_at_v2           float64
#  6    site_ba_prc_rec_at_v2           float64
#  7    n_species_nfi                   float64
#  8    top1_species                    float64
#  9    top1_species_ba_1_mean          float64
#  10   top1_species_ba_1_sd            float64
#  11   top1_species_age13_mean         float64
#  12   top1_species_age13_sd           float64
#  13   top1_species_ir5_mean           float64
#  14   top1_species_ir5_sd             float64
#  15   top1_species_v_mean             float64
#  16   top1_species_v_sd               float64
#  17   top1_species_htot_mean          float64
#  18   top1_species_htot_sd            float64
#  19   top2_species                    object
#  20   top2_species_ba_1_mean          float64
#  21   top2_species_ba_1_sd            float64
#  22   top2_species_age13_mean         float64
#  23   top2_species_age13_sd           float64
#  24   top2_species_ir5_mean           float64
#  25   top2_species_ir5_sd             float64
#  26   top2_species_v_mean             float64
#  27   top2_species_v_sd               float64
#  28   top2_species_htot_mean          float64
#  29   top2_species_htot_sd            float64
#  30   top3_species                    object
#  31   top3_species_ba_1_mean          float64
#  32   top3_species_ba_1_sd            float64
#  33   top3_species_age13_mean         float64
#  34   top3_species_age13_sd           float64
#  35   top3_species_ir5_mean           float64
#  36   top3_species_ir5_sd             float64
#  37   top3_species_v_mean             float64
#  38   top3_species_v_sd               float64
#  39   top3_species_htot_mean          float64
#  40   top3_species_htot_sd            float64
#  41   dom_nr1_tree_class_fct          object
#  42   dom_nr1_tree_class_ba_abs       float64
#  43   dom_nr1_tree_class_ba_prc       float64
#  44   dom_nr2_tree_class_fct          object
#  45   dom_nr2_tree_class_ba_abs       float64
#  46   dom_nr2_tree_class_ba_prc       float64
#  47   dom_nr3_tree_class_fct          object
#  48   dom_nr3_tree_class_ba_abs       float64
#  49   dom_nr3_tree_class_ba_prc       float64
#  50   dom_rest_tree_class_fct         object
#  51   dom_rest_tree_class_ba_abs      float64
#  52   dom_rest_tree_class_ba_prc      float64
#  53   ntrees_1                        float64
#  54   ntrees_2                        float64
#  55   perc_trees_burn                 float64
#  56   perc_trees_game                 float64
#  57   perc_trees_footdmg              float64
#  58   perc_trees_rotcore              float64
#  59   perc_trees_frost_v1             float64
#  60   perc_trees_frost_v2             float64
#  61   perc_trees_mistletoe_v1         float64
#  62   perc_trees_mistletoe_v2         float64
#  63   perc_trees_firrust_v1           float64
#  64   perc_trees_firrust_v2           float64
#  65   a                               int64
#  66   tree_id                         object
#  67   visit_1                         int64
#  68   visit_2                         float64
#  69   revisit_state                   object
#  70   hrb                             float64
#  71   campagne_1                      int64
#  72   campagne_2                      float64
#  73   visite_1                        int64
#  74   visite_2                        float64
#  75   c13_1                           float64
#  76   c13_2                           float64
#  77   mortb_1                         float64
#  78   mortb_2                         float64
#  79   sfdorge_1                       float64
#  80   sfdorge_2                       float64
#  81   sfgeliv_1                       float64
#  82   sfgeliv_2                       float64
#  83   sfgui_1                         float64
#  84   sfgui_2                         float64
#  85   veget                           object
#  86   q1                              float64
#  87   q2                              float64
#  88   q3                              float64
#  89   age13                           float64
#  90   age                             float64
#  91   c0                              float64
#  92   htot                            float64
#  93   hdec                            float64
#  94   ddec                            float64
#  95   lfsd                            float64
#  96   v                               float64
#  97   w                               float64
#  98   r                               float64
#  99   ir5                             float64
#  100  ir1                             float64
#  101  espar                           object
#  102  datemort                        float64
#  103  ori                             float64
#  104  tige                            float64
#  105  forme                           float64
#  106  tetard                          float64
#  107  cible                           float64
#  108  lib                             float64
#  109  simplif                         float64
#  110  acci                            float64
#  111  clon                            object
#  112  mes_c13                         float64
#  113  decoupe                         float64
#  114  sfcoeur                         float64
#  115  sfpied                          float64
#  116  deggib                          float64
#  117  veget5                          object
#  118  qualite                         object
#  119  lon_fr                          float64
#  120  lat_fr                          float64
#  121  dep                             object
#  122  ser                             object
#  123  dpyr                            float64
#  124  anpyr                           float64
#  125  pbuis                           float64
#  126  lat                             float64
#  127  lon                             float64
#  128  incid_1                         float64
#  129  incid_2                         float64
#  130  nincid_1                        float64
#  131  nincid_2                        float64
#  132  tpespar1_1                      object
#  133  tpespar1_2                      object
#  134  tpespar2_1                      object
#  135  tpespar2_2                      object
#  136  bplant_1                        float64
#  137  bplant_2                        float64
#  138  iplant_1                        float64
#  139  iplant_2                        float64
#  140  videpeuplier_1                  float64
#  141  videpeuplier_2                  float64
#  142  csa_1                           float64
#  143  csa_2                           float64
#  144  bois_1                          float64
#  145  bois_2                          float64
#  146  peupnr_1                        float64
#  147  peupnr_2                        float64
#  148  utip_1                          object
#  149  utip_2                          object
#  150  autut_1                         object
#  151  autut_2                         object
#  152  tform_1                         float64
#  153  tform_2                         float64
#  154  dc_1                            float64
#  155  dc_2                            float64
#  156  gest                            float64
#  157  elag                            float64
#  158  dist                            float64
#  159  acces                           float64
#  160  iti                             float64
#  161  asperite                        float64
#  162  pentexp                         float64
#  163  portn                           float64
#  164  portance                        float64
#  165  orniere                         float64
#  166  dcespar1                        object
#  167  dcespar2                        object
#  168  tplant                          object
#  169  videplant                       object
#  170  entp                            float64
#  171  tcat10                          float64
#  172  uta1                            object
#  173  uta2                            object
#  174  plisi                           float64
#  175  cslisi                          object
#  176  elisi                           float64
#  177  andain                          float64
#  178  bord                            float64
#  179  integr                          object
#  180  tm2                             float64
#  181  sfo                             float64
#  182  cam                             float64
#  183  prelev5                         float64
#  184  def5                            float64
#  185  instp5                          object
#  186  nlisi5                          float64
#  187  sver                            object
#  188  census_interval                 object
#  189  tree_state_1                    object
#  190  alive_but_injured_1             object
#  191  tree_state_2                    object
#  192  alive_but_injured_2             object
#  193  mode_of_death                   object
#  194  tree_state_change               object
#  195  tree_class                      object
#  196  species_lat                     object
#  197  genus_lat                       object
#  198  family_lat                      object
#  199  order_lat                       object
#  200  espar_red                       float64
#  201  age_class                       object
#  202  height_class                    object
#  203  shadow_growth                   object
#  204  c13_change_abs_yr               float64
#  205  c13_change_perc_yr              float64
#  206  dbh_1                           float64
#  207  dbh_2                           float64
#  208  dbh_change_abs_yr               float64
#  209  dbh_change_perc_yr              float64
#  210  ba_1                            float64
#  211  ba_2                            float64
#  212  ba_change_abs_yr                float64
#  213  ba_change_perc_yr               float64
#  214  avg_growth_height_meter_per_yr  float64
#  215  avg_growth_ba_per_year          float64
#  216  land_use                        object
#  217  land_use_change                 object
#  218  cover_change                    object
#  219  human_activity                  object
#  220  human_activity_var              object
#  221  gre                             object
#  222  strate                          object
#  223  tca                             float64
#  224  tcl                             float64
#  225  p1525                           float64
#  226  p7ares                          float64
#  227  dateeco                         object
#  228  topo                            float64
#  229  obstopo                         float64
#  230  expo                            float64
#  231  msud                            float64
#  232  masque                          float64
#  233  pent2                           float64
#  234  obschemin                       float64
#  235  humus                           float64
#  236  oln                             float64
#  237  olt                             float64
#  238  ofr                             float64
#  239  olv                             float64
#  240  oh                              float64
#  241  tsol                            float64
#  242  prof1                           float64
#  243  prof2                           float64
#  244  obsprof                         float64
#  245  text1                           float64
#  246  text2                           object
#  247  obspedo                         object
#  248  roche                           float64
#  249  obsroc                          float64
#  250  affroc                          object
#  251  cai40                           object
#  252  cailloux                        object
#  253  typcai                          float64
#  254  afpla                           float64
#  255  pgley                           object
#  256  pox                             object
#  257  ppseudo                         object
#  258  obshydr                         float64
#  259  pcalc                           object
#  260  pcalf                           object
#  261  obsriv                          float64
#  262  obsriv2                         float64
#  263  typriv                          float64
#  264  distriv                         float64
#  265  denivriv                        float64
#  266  lign2                           float64
#  267  lign1                           float64
#  268  herb                            float64
#  269  mousse                          float64
#  270  obsveget                        float64
#  271  obsdate                         float64
# dtypes: float64(201), int64(5), object(66)
# memory usage: 2.7+ GB
# None

# %%
all_tree_lvl_vars = [
    # From NFI data
    "acci",
    "cible",
    "clon",
    "decoupe",
    "deggib",
    "espar",
    "forme",
    "ori",
    "qualite",
    "simplif",
    "tetard",
    "tige",
    "veget",
    "veget5",
    "a",
    "datemort",
    "lib",
    "age",
    "age13",
    "c0",
    "c13",
    "ddec",
    "hdec",
    "hrb",
    "htot",
    "ir1",
    "ir5",
    "lfsd",
    "mes_c13",
    "q1",
    "q2",
    "q3",
    "r",
    "v",
    "w",
    "mortb",
    "sfcoeur",
    "sfpied",
    "sfdorge",
    "sfgeliv",
    "sfgui",
    "espar_bm",
    "frepli",
    "dbm",
    "decomp",
    "espar_c",
    "p1525",
    "p7ares",
    "strate",
    "tca",
    "tcl",
    # From derivatives
    "alive_but_injured_1",
    "alive_but_injured_2",
    "family_lat",
    "genus_lat",
    "mode_of_death",
    "order_lat",
    "revisit_state",
    "shadow_growth",
    "species_lat",
    "tree_class",
    "tree_id",
    "tree_state_1",
    "tree_state_2",
    "tree_state_change",
    "espar_red",
    "avg_growth_ba_per_year",
    "avg_growth_height_meter_per_yr",
    "ba_1",
    "ba_2",
    "ba_change_abs_yr",
    "ba_change_perc_yr",
    "c13_change_abs_yr",
    "c13_change_perc_yr",
    "dbh_1",
    "dbh_2",
    "dbh_change_abs_yr",
    "dbh_change_perc_yr",
    "visit_1",
    "visit_2",
    "age_class",
    "height_class",
    "census_interval",
]

# Attach suffixes to column names
suffix_1 = [suffix + "_1" for suffix in all_tree_lvl_vars]
suffix_2 = [suffix + "_2" for suffix in all_tree_lvl_vars]

# Create a list of all tree level variables
all_tree_lvl_vars = all_tree_lvl_vars + suffix_1 + suffix_2

# %%
raw_tree = raw.copy()

for var in raw_tree.columns:
    if var in ["idp", "campagne_1"]:
        next
    if var not in all_tree_lvl_vars:
        raw_tree = raw_tree.drop(columns=[var], errors="ignore")

# %%
raw_loc = raw.copy()

for var in raw_loc.columns:
    if var in ["idp", "campagne_1"]:
        next
    if var in all_tree_lvl_vars:
        raw_loc = raw_loc.drop(columns=[var], errors="ignore")

raw_loc = raw_loc.drop_duplicates()

# %%
print(f"All raw data: {raw.shape}")
print(f"Tree-level data: {raw_tree.shape}")
print(f"Location-level data: {raw_loc.shape}")
print(f"Number of unique locations: {raw['idp'].nunique()}")
# Out:
# All raw data: (1318400, 272)
# Tree-level data: (1318400, 83)
# Location-level data: (104554, 189)
# Number of unique locations: 102924

# %%
grouped = raw_loc.groupby("idp").size().reset_index(name="count")
filtered = grouped[grouped["count"] > 1]
filtered
# Out:
#           idp  count
# 20        172      2
# 22        179      2
# 82        605      2
# 102       780      2
# 118       894      2
# ...       ...    ...
# 32389  478510      2
# 32392  478545      2
# 32491  479819      2
# 32524  480200      2
# 32540  480492      2
#
# [1630 rows x 2 columns]

# %%
test = raw_loc[raw_loc["idp"] == 480200]

for col in test.columns:
    if test[col].nunique() > 1:
        print(f"{test[col].nunique()} unique values in \t {col}")

# %%
ProfileReport(raw_tree, title="Tree-level data", minimal=True, dark_mode=True).to_file(
    "report_tree_level_raw_data.html"
)
ProfileReport(
    raw_loc, title="Location-level data", minimal=True, dark_mode=True
).to_file("report_location_level_raw_data.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
raw_tree_subset = raw_tree.copy().query("campagne_1 > 2009 and campagne_1 < 2016")
raw_loc_subset = raw_loc.copy().query("campagne_1 > 2009 and campagne_1 < 2016")

ProfileReport(
    raw_tree_subset,
    title="Tree-level data SUBSET FOR CAMPAGNE 2010-2016",
    minimal=True,
    dark_mode=True,
).to_file("report_tree_level_raw_data_CAMPAGNE_SUBSET.html")
ProfileReport(
    raw_loc_subset,
    title="Location-level data SUBSET FOR CAMPAGNE 2010-2016",
    minimal=True,
    dark_mode=True,
).to_file("report_location_level_raw_data_CAMPAGNE_SUBSET.html")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/repos/padasch/ifn_analysis/ifna-venv/lib/python3.10/site-packages/pandas/core/computation/scope.py:233, in Scope.resolve(self, key, is_local)
#     232 if self.has_resolvers:
# --> 233     return self.resolvers[key]
#     235 # if we're here that means that we have no locals and we also have
#     236 # no resolvers
#
# File ~/anaconda3/lib/python3.10/collections/__init__.py:986, in ChainMap.__getitem__(self, key)
#     985         pass
# --> 986 return self.__missing__(key)
#
# File ~/anaconda3/lib/python3.10/collections/__init__.py:978, in ChainMap.__missing__(self, key)
#     977 def __missing__(self, key):
# --> 978     raise KeyError(key)
#
# KeyError: 'campagne_1'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/repos/padasch/ifn_analysis/ifna-venv/lib/python3.10/site-packages/pandas/core/computation/scope.py:244, in Scope.resolve(self, key, is_local)
#     240 try:
#     241     # last ditch effort we look in temporaries
#     242     # these are created when parsing indexing expressions
#     243     # e.g., df[df > 0]
# --> 244     return self.temps[key]
#     245 except KeyError as err:
#
# KeyError: 'campagne_1'
#
# The above exception was the direct cause of the following exception:
#
# UndefinedVariableError                    Traceback (most recent call last)
# /Users/pascal/repos/padasch/ifn_analysis/python/00_process_nfi_data/report_for_raw_nfi_dataset.ipynb Cell 12 line 1
# ----> <a href='vscode-notebook-cell:/Users/pascal/repos/padasch/ifn_analysis/python/00_process_nfi_data/report_for_raw_nfi_dataset.ipynb#X24sZmlsZQ%3D%3D?line=0'>1</a> raw_tree_subset = raw_tree.copy().query("campagne_1 > 2009 and campagne_1 < 2016")
#       <a href='vscode-notebook-cell:/Users/pascal/repos/padasch/ifn_analysis/python/00_process_nfi_data/report_for_raw_nfi_dataset.ipynb#X24sZmlsZQ%3D%3D?line=1'>2</a> raw_loc_subset = raw_loc.copy().query("campagne_1 > 2009 and campagne_1 < 2016")
#       <a href='vscode-notebook-cell:/Users/pascal/repos/padasch/ifn_analysis/python/00_process_nfi_data/report_for_raw_nfi_dataset.ipynb#X24sZmlsZQ%3D%3D?line=3'>4</a> ProfileReport(
#       <a href='vscode-notebook-cell:/Users/pascal/repos/padasch/ifn_analysis/python/00_process_nfi_data/report_for_raw_nfi_dataset.ipynb#X24sZmlsZQ%3D%3D?line=4'>5</a>     raw_tree_subset,
#       <a href='vscode-notebook-cell:/Users/pascal/repos/padasch/ifn_analysis/python/00_process_nfi_data/report_for_raw_nfi_dataset.ipynb#X24sZmlsZQ%3D%3D?line=5'>6</a>     title="Tree-level data SUBSET FOR CAMPAGNE 2010-2016",
#       <a href='vscode-notebook-cell:/Users/pascal/repos/padasch/ifn_analysis/python/00_process_nfi_data/report_for_raw_nfi_dataset.ipynb#X24sZmlsZQ%3D%3D?line=6'>7</a>     minimal=True,
#       <a href='vscode-notebook-cell:/Users/pascal/repos/padasch/ifn_analysis/python/00_process_nfi_data/report_for_raw_nfi_dataset.ipynb#X24sZmlsZQ%3D%3D?line=7'>8</a>     dark_mode=True,
#       <a href='vscode-notebook-cell:/Users/pascal/repos/padasch/ifn_analysis/python/00_process_nfi_data/report_for_raw_nfi_dataset.ipynb#X24sZmlsZQ%3D%3D?line=8'>9</a> ).to_file("report_tree_level_raw_data_CAMPAGNE_SUBSET.html")
#
# File ~/repos/padasch/ifn_analysis/ifna-venv/lib/python3.10/site-packages/pandas/core/frame.py:4440, in DataFrame.query(self, expr, inplace, **kwargs)
#    4438 kwargs["level"] = kwargs.pop("level", 0) + 1
#    4439 kwargs["target"] = None
# -> 4440 res = self.eval(expr, **kwargs)
#    4442 try:
#    4443     result = self.loc[res]
#
# File ~/repos/padasch/ifn_analysis/ifna-venv/lib/python3.10/site-packages/pandas/core/frame.py:4566, in DataFrame.eval(self, expr, inplace, **kwargs)
#    4563     kwargs["target"] = self
#    4564 kwargs["resolvers"] = tuple(kwargs.get("resolvers", ())) + resolvers
# -> 4566 return _eval(expr, inplace=inplace, **kwargs)
#
# File ~/repos/padasch/ifn_analysis/ifna-venv/lib/python3.10/site-packages/pandas/core/computation/eval.py:336, in eval(expr, parser, engine, local_dict, global_dict, resolvers, level, target, inplace)
#     327 # get our (possibly passed-in) scope
#     328 env = ensure_scope(
#     329     level + 1,
#     330     global_dict=global_dict,
#    (...)
#     333     target=target,
#     334 )
# --> 336 parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#     338 if engine == "numexpr" and (
#     339     is_extension_array_dtype(parsed_expr.terms.return_type)
#     340     or getattr(parsed_expr.terms, "operand_types", None) is not None
#    (...)
#     344     )
#     345 ):
#     346     warnings.warn(
#     347         "Engine has switched to 'python' because numexpr does not support "
#     348         "extension array dtypes. Please set your engine to python manually.",
#     349         RuntimeWarning,
#     350         stacklevel=find_stack_level(),
#     351     )
#
# File ~/repos/padasch/ifn_analysis/ifna-venv/lib/python3.10/site-packages/pandas/core/computation/expr.py:809, in Expr.__init__(self, expr, engine, parser, env, level)
#     807 self.parser = parser
#     808 self._visitor = PARSERS[parser](self.env, self.engine, self.parser)
# --> 809 self.terms = self.parse()
#
# File ~/repos/padasch/ifn_analysis/ifna-venv/lib/python3.10/site-packages/pandas/core/computation/expr.py:828, in Expr.parse(self)
#     824 def parse(self):
#     825     """
#     826     Parse an expression.
#     827     """
# --> 828     return self._visitor.visit(self.expr)
#
# File ~/repos/padasch/ifn_analysis/ifna-venv/lib/python3.10/site-packages/pandas/core/computation/expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = f"visit_{type(node).__name__}"
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File ~/repos/padasch/ifn_analysis/ifna-venv/lib/python3.10/site-packages/pandas/core/computation/expr.py:421, in BaseExprVisitor.visit_Module(self, node, **kwargs)
#     419     raise SyntaxError("only a single expression is allowed")
#     420 expr = node.body[0]
# --> 421 return self.visit(expr, **kwargs)
#
# File ~/repos/padasch/ifn_analysis/ifna-venv/lib/python3.10/site-packages/pandas/core/computation/expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = f"visit_{type(node).__name__}"
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File ~/repos/padasch/ifn_analysis/ifna-venv/lib/python3.10/site-packages/pandas/core/computation/expr.py:424, in BaseExprVisitor.visit_Expr(self, node, **kwargs)
#     423 def visit_Expr(self, node, **kwargs):
# --> 424     return self.visit(node.value, **kwargs)
#
# File ~/repos/padasch/ifn_analysis/ifna-venv/lib/python3.10/site-packages/pandas/core/computation/expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = f"visit_{type(node).__name__}"
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File ~/repos/padasch/ifn_analysis/ifna-venv/lib/python3.10/site-packages/pandas/core/computation/expr.py:746, in BaseExprVisitor.visit_BoolOp(self, node, **kwargs)
#     743     return self._maybe_evaluate_binop(op, node.op, lhs, rhs)
#     745 operands = node.values
# --> 746 return reduce(visitor, operands)
#
# File ~/repos/padasch/ifn_analysis/ifna-venv/lib/python3.10/site-packages/pandas/core/computation/expr.py:739, in BaseExprVisitor.visit_BoolOp.<locals>.visitor(x, y)
#     738 def visitor(x, y):
# --> 739     lhs = self._try_visit_binop(x)
#     740     rhs = self._try_visit_binop(y)
#     742     op, op_class, lhs, rhs = self._maybe_transform_eq_ne(node, lhs, rhs)
#
# File ~/repos/padasch/ifn_analysis/ifna-venv/lib/python3.10/site-packages/pandas/core/computation/expr.py:735, in BaseExprVisitor._try_visit_binop(self, bop)
#     733 if isinstance(bop, (Op, Term)):
#     734     return bop
# --> 735 return self.visit(bop)
#
# File ~/repos/padasch/ifn_analysis/ifna-venv/lib/python3.10/site-packages/pandas/core/computation/expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = f"visit_{type(node).__name__}"
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File ~/repos/padasch/ifn_analysis/ifna-venv/lib/python3.10/site-packages/pandas/core/computation/expr.py:719, in BaseExprVisitor.visit_Compare(self, node, **kwargs)
#     717     op = self.translate_In(ops[0])
#     718     binop = ast.BinOp(op=op, left=node.left, right=comps[0])
# --> 719     return self.visit(binop)
#     721 # recursive case: we have a chained comparison, a CMP b CMP c, etc.
#     722 left = node.left
#
# File ~/repos/padasch/ifn_analysis/ifna-venv/lib/python3.10/site-packages/pandas/core/computation/expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = f"visit_{type(node).__name__}"
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File ~/repos/padasch/ifn_analysis/ifna-venv/lib/python3.10/site-packages/pandas/core/computation/expr.py:535, in BaseExprVisitor.visit_BinOp(self, node, **kwargs)
#     534 def visit_BinOp(self, node, **kwargs):
# --> 535     op, op_class, left, right = self._maybe_transform_eq_ne(node)
#     536     left, right = self._maybe_downcast_constants(left, right)
#     537     return self._maybe_evaluate_binop(op, op_class, left, right)
#
# File ~/repos/padasch/ifn_analysis/ifna-venv/lib/python3.10/site-packages/pandas/core/computation/expr.py:455, in BaseExprVisitor._maybe_transform_eq_ne(self, node, left, right)
#     453 def _maybe_transform_eq_ne(self, node, left=None, right=None):
#     454     if left is None:
# --> 455         left = self.visit(node.left, side="left")
#     456     if right is None:
#     457         right = self.visit(node.right, side="right")
#
# File ~/repos/padasch/ifn_analysis/ifna-venv/lib/python3.10/site-packages/pandas/core/computation/expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = f"visit_{type(node).__name__}"
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File ~/repos/padasch/ifn_analysis/ifna-venv/lib/python3.10/site-packages/pandas/core/computation/expr.py:548, in BaseExprVisitor.visit_Name(self, node, **kwargs)
#     547 def visit_Name(self, node, **kwargs):
# --> 548     return self.term_type(node.id, self.env, **kwargs)
#
# File ~/repos/padasch/ifn_analysis/ifna-venv/lib/python3.10/site-packages/pandas/core/computation/ops.py:86, in Term.__init__(self, name, env, side, encoding)
#      84 tname = str(name)
#      85 self.is_local = tname.startswith(LOCAL_TAG) or tname in DEFAULT_GLOBALS
# ---> 86 self._value = self._resolve_name()
#      87 self.encoding = encoding
#
# File ~/repos/padasch/ifn_analysis/ifna-venv/lib/python3.10/site-packages/pandas/core/computation/ops.py:110, in Term._resolve_name(self)
#     105 if local_name in self.env.scope and isinstance(
#     106     self.env.scope[local_name], type
#     107 ):
#     108     is_local = False
# --> 110 res = self.env.resolve(local_name, is_local=is_local)
#     111 self.update(res)
#     113 if hasattr(res, "ndim") and res.ndim > 2:
#
# File ~/repos/padasch/ifn_analysis/ifna-venv/lib/python3.10/site-packages/pandas/core/computation/scope.py:246, in Scope.resolve(self, key, is_local)
#     244     return self.temps[key]
#     245 except KeyError as err:
# --> 246     raise UndefinedVariableError(key, is_local) from err
#
# UndefinedVariableError: name 'campagne_1' is not defined
