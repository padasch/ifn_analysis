# %% [markdown]
# # Settings for Download: ERA5 Daily Aggregates
#
# [ECMWF/ERA5/DAILY](https://developers.google.com/earth-engine/datasets/catalog/ECMWF_ERA5_DAILY)

# %%
# ADJUST ONLY THESE PARAMETERS!

# Debug settings
skip_to_i = 0  # 0 = no skip | If loop broke, resume by setting this i to where you want to continue
first_5000_sites = False

# Timescale of Interest
my_plus_years = 5  # Years to add after first visit
my_minus_years = 2  # Years to add before first visit
my_first_date = "-01-01"  # First date of first year "-MM-DD"
my_last_date = "-12-31"  # Last date of last year "-MM-DD"

# Dataset of Interest
product = "ECMWF/ERA5/DAILY"
product_start_date = "1979-01-02"
product_end_date = "2020-07-09"
product_scale = 27830

output_scale = product_scale
output_folder = "gee-raw-data/era5-daily/minimum_2m_air_temperature"

my_bands = [
    # "mean_2m_air_temperature",
    "minimum_2m_air_temperature"
    # "maximum_2m_air_temperature",
    # "dewpoint_2m_temperature",
    # "total_precipitation",
    # "surface_pressure",
    # "mean_sea_level_pressure",
    # "u_component_of_wind_10m",
    # "v_component_of_wind_10m"
]

# %%
# ADJUST IF NEEDED
download_only_remaining_files = False

# Import Libraries
import pandas as pd
import numpy as np
import os
import sys

sys.path.insert(0, "../../src")

# Import Functions
from run_mp import *
from gee_data_wrangling import *
from gee_data_download import *

# Load data from csv
data = get_nfi_coordinates_site_year(with_idp=False)

# Clean first and last date for download routine
data_clean = adjust_first_last_date(
    df=data,
    plus_years=my_plus_years,
    minus_years=my_minus_years,
    first_date=my_first_date,
    last_date=my_last_date,
)

# -----------------------
# Shortcut to only download remaining files
if download_only_remaining_files:
    # list all files in output_folder with .feather ending
    files = [f for f in os.listdir(output_folder) if f.endswith(".feather")]

    # extract the number from the filenames just before the '.feather' ending
    ids = [int(item.split("_")[1].split(".")[0]) for item in files]

    # filter data_clean to hold only id that are not in the folder already
    data_clean = data_clean[~data_clean["SiteID"].isin(ids)]
    # data_clean
# -----------------------

# Split sites into groups of ten, to use all cores
sequence = np.arange(1, 11)  # This creates an array [1, 2, ..., 10]
repeated_sequence = np.tile(sequence, len(data_clean) // len(sequence) + 1)[
    : len(data_clean)
]
data_clean["group_id"] = repeated_sequence

# Create a list of all the groups
grouped = data_clean.groupby("group_id")
df_list = [group for name, group in grouped]

# Parallelize the download
run_mp(
    download_gee_data_PARALLEL,
    df_list,
    combine_func=pd.concat,
    progress_bar=True,
    num_cores=10,
    product=product,
    my_bands=my_bands,
    product_start_date=product_start_date,
    product_end_date=product_end_date,
    product_scale=product_scale,
    output_scale=output_scale,
    output_folder=output_folder,
    verbose=False,
)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]*** Earth Engine *** Share your feedback by taking our Annual Developer Satisfaction Survey: https://google.qualtrics.com/jfe/form/SV_doiqkQG3NJ1t8IS?source=API
#  10%|█         | 1/10 [00:04<00:38,  4.28s/it]*** Earth Engine *** Share your feedback by taking our Annual Developer Satisfaction Survey: https://google.qualtrics.com/jfe/form/SV_doiqkQG3NJ1t8IS?source=API
# *** Earth Engine *** Share your feedback by taking our Annual Developer Satisfaction Survey: https://google.qualtrics.com/jfe/form/SV_doiqkQG3NJ1t8IS?source=API
# *** Earth Engine *** Share your feedback by taking our Annual Developer Satisfaction Survey: https://google.qualtrics.com/jfe/form/SV_doiqkQG3NJ1t8IS?source=API
# *** Earth Engine *** Share your feedback by taking our Annual Developer Satisfaction Survey: https://google.qualtrics.com/jfe/form/SV_doiqkQG3NJ1t8IS?source=API
# *** Earth Engine *** Share your feedback by taking our Annual Developer Satisfaction Survey: https://google.qualtrics.com/jfe/form/SV_doiqkQG3NJ1t8IS?source=API
# *** Earth Engine *** Share your feedback by taking our Annual Developer Satisfaction Survey: https://google.qualtrics.com/jfe/form/SV_doiqkQG3NJ1t8IS?source=API
# *** Earth Engine *** Share your feedback by taking our Annual Developer Satisfaction Survey: https://google.qualtrics.com/jfe/form/SV_doiqkQG3NJ1t8IS?source=API
#  70%|███████   | 7/10 [00:05<00:02,  1.39it/s]
# *** Earth Engine *** Share your feedback by taking our Annual Developer Satisfaction Survey: https://google.qualtrics.com/jfe/form/SV_doiqkQG3NJ1t8IS?source=API
# *** Earth Engine *** Share your feedback by taking our Annual Developer Satisfaction Survey: https://google.qualtrics.com/jfe/form/SV_doiqkQG3NJ1t8IS?source=API
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/Users/pascal/anaconda3/lib/python3.10/concurrent/futures/process.py", line 246, in _process_worker
#     r = call_item.fn(*call_item.args, **call_item.kwargs)
#   File "/Users/pascal/repos/padasch/ifn_analysis/python/01_download_raw_gee_data/../../src/gee_data_download.py", line 194, in download_gee_data_PARALLEL
#     start_date = larger_date(my_group.iloc[i, 3],  product_start_date),
#   File "/Users/pascal/repos/padasch/ifn_analysis/python/01_download_raw_gee_data/../../src/gee_data_download.py", line 85, in larger_date
#     date1 = datetime.datetime.strptime(date_str1, '%Y-%m-%d')
# TypeError: strptime() argument 1 must be str, not numpy.float64
# """
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# /Users/pascal/repos/padasch/ifn_analysis/python/01_download_raw_gee_data/download_era5_daily_minimum_2m_air_temperature.ipynb Cell 3 line 5
#      <a href='vscode-notebook-cell:/Users/pascal/repos/padasch/ifn_analysis/python/01_download_raw_gee_data/download_era5_daily_minimum_2m_air_temperature.ipynb#W2sZmlsZQ%3D%3D?line=51'>52</a> df_list = [group for name, group in grouped]
#      <a href='vscode-notebook-cell:/Users/pascal/repos/padasch/ifn_analysis/python/01_download_raw_gee_data/download_era5_daily_minimum_2m_air_temperature.ipynb#W2sZmlsZQ%3D%3D?line=53'>54</a> # Parallelize the download
# ---> <a href='vscode-notebook-cell:/Users/pascal/repos/padasch/ifn_analysis/python/01_download_raw_gee_data/download_era5_daily_minimum_2m_air_temperature.ipynb#W2sZmlsZQ%3D%3D?line=54'>55</a> run_mp(
#      <a href='vscode-notebook-cell:/Users/pascal/repos/padasch/ifn_analysis/python/01_download_raw_gee_data/download_era5_daily_minimum_2m_air_temperature.ipynb#W2sZmlsZQ%3D%3D?line=55'>56</a>     download_gee_data_PARALLEL,
#      <a href='vscode-notebook-cell:/Users/pascal/repos/padasch/ifn_analysis/python/01_download_raw_gee_data/download_era5_daily_minimum_2m_air_temperature.ipynb#W2sZmlsZQ%3D%3D?line=56'>57</a>     df_list,
#      <a href='vscode-notebook-cell:/Users/pascal/repos/padasch/ifn_analysis/python/01_download_raw_gee_data/download_era5_daily_minimum_2m_air_temperature.ipynb#W2sZmlsZQ%3D%3D?line=57'>58</a>     combine_func=pd.concat,
#      <a href='vscode-notebook-cell:/Users/pascal/repos/padasch/ifn_analysis/python/01_download_raw_gee_data/download_era5_daily_minimum_2m_air_temperature.ipynb#W2sZmlsZQ%3D%3D?line=58'>59</a>     progress_bar=True,
#      <a href='vscode-notebook-cell:/Users/pascal/repos/padasch/ifn_analysis/python/01_download_raw_gee_data/download_era5_daily_minimum_2m_air_temperature.ipynb#W2sZmlsZQ%3D%3D?line=59'>60</a>     num_cores=10,
#      <a href='vscode-notebook-cell:/Users/pascal/repos/padasch/ifn_analysis/python/01_download_raw_gee_data/download_era5_daily_minimum_2m_air_temperature.ipynb#W2sZmlsZQ%3D%3D?line=60'>61</a>     product=product,
#      <a href='vscode-notebook-cell:/Users/pascal/repos/padasch/ifn_analysis/python/01_download_raw_gee_data/download_era5_daily_minimum_2m_air_temperature.ipynb#W2sZmlsZQ%3D%3D?line=61'>62</a>     my_bands=my_bands,
#      <a href='vscode-notebook-cell:/Users/pascal/repos/padasch/ifn_analysis/python/01_download_raw_gee_data/download_era5_daily_minimum_2m_air_temperature.ipynb#W2sZmlsZQ%3D%3D?line=62'>63</a>     product_start_date=product_start_date,
#      <a href='vscode-notebook-cell:/Users/pascal/repos/padasch/ifn_analysis/python/01_download_raw_gee_data/download_era5_daily_minimum_2m_air_temperature.ipynb#W2sZmlsZQ%3D%3D?line=63'>64</a>     product_end_date=product_end_date,
#      <a href='vscode-notebook-cell:/Users/pascal/repos/padasch/ifn_analysis/python/01_download_raw_gee_data/download_era5_daily_minimum_2m_air_temperature.ipynb#W2sZmlsZQ%3D%3D?line=64'>65</a>     product_scale=product_scale,
#      <a href='vscode-notebook-cell:/Users/pascal/repos/padasch/ifn_analysis/python/01_download_raw_gee_data/download_era5_daily_minimum_2m_air_temperature.ipynb#W2sZmlsZQ%3D%3D?line=65'>66</a>     output_scale=output_scale,
#      <a href='vscode-notebook-cell:/Users/pascal/repos/padasch/ifn_analysis/python/01_download_raw_gee_data/download_era5_daily_minimum_2m_air_temperature.ipynb#W2sZmlsZQ%3D%3D?line=66'>67</a>     output_folder=output_folder,
#      <a href='vscode-notebook-cell:/Users/pascal/repos/padasch/ifn_analysis/python/01_download_raw_gee_data/download_era5_daily_minimum_2m_air_temperature.ipynb#W2sZmlsZQ%3D%3D?line=67'>68</a>     verbose=False,
#      <a href='vscode-notebook-cell:/Users/pascal/repos/padasch/ifn_analysis/python/01_download_raw_gee_data/download_era5_daily_minimum_2m_air_temperature.ipynb#W2sZmlsZQ%3D%3D?line=68'>69</a> )
#
# File ~/repos/padasch/ifn_analysis/python/01_download_raw_gee_data/../../src/run_mp.py:47, in run_mp(map_func, arg_list, combine_func, num_cores, split_arg, progress_bar, **kwargs)
#      44         results = []
#      46         for future in futures:
# ---> 47             result = future.result()
#      48             results.append(result)
#      50 if combine_func is not None:
#
# File ~/anaconda3/lib/python3.10/concurrent/futures/_base.py:458, in Future.result(self, timeout)
#     456     raise CancelledError()
#     457 elif self._state == FINISHED:
# --> 458     return self.__get_result()
#     459 else:
#     460     raise TimeoutError()
#
# File ~/anaconda3/lib/python3.10/concurrent/futures/_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# TypeError: strptime() argument 1 must be str, not numpy.float64
