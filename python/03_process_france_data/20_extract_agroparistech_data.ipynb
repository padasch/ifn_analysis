# %% [markdown]
# # Silvae / Agroparistech Data
#
# - Accessed latest on 2023-12-08: https://silvae.agroparistech.fr/home/?page_id=2683

# %% [markdown]
# ## Libraries

# %%
# Magic
# %load_ext autoreload
# %autoreload 2

from tqdm import tqdm
import rasterio
from rasterio import windows

import pandas as pd
import glob
import numpy as np
import os
import chime
import matplotlib.pyplot as plt

chime.theme("mario")

# Import Functions
import sys

sys.path.insert(0, "../../src")
from run_mp import *
from extract_raster_values import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Clean where NA value is present, based on files' NA value
def clean_na_in_agroparistech(df_mp, df_vars):
    for col in df_mp.drop(columns=["idp", "x_fr", "y_fr"]).columns:
        # print(col)

        current_na = df_vars.query("variables == @col")["na_value"].iloc[0]
        # print("For column: ", df_mp.columns[i], "NA value is: ", current_na)

        for j in range(df_mp.shape[0]):
            if df_mp.at[j, col] == current_na:
                df_mp.at[j, col] = np.nan
    return df_mp

# %%
def get_file_size(filename):
    """Get file size in megabytes."""
    return os.path.getsize(filename) / (1024 * 1024)


def calculate_splits(file_size, max_mb):
    """Calculate the number of splits based on file size and maximum MB per split."""
    return max(1, int(file_size / max_mb))


def get_splits(height, num_splits):
    """Calculate window positions for splitting the raster with overlap."""
    split_height = height // num_splits
    overlap = int(split_height * 0.50)  # 10% overlap

    for i in range(num_splits):
        start = max(0, i * split_height - overlap)
        end = (
            min(height, (i + 1) * split_height + overlap)
            if i < num_splits - 1
            else height
        )
        yield (start, end - start)


def split_raster(input_raster, subfolder, max_mb):
    """Split a raster into subfiles based on maximum MB per file."""

    # Check file size and calculate number of splits
    file_size = get_file_size(input_raster)
    num_splits = calculate_splits(file_size, max_mb)

    # Create subfolder if it doesn't exist
    ffolder = f"{subfolder}/subrasters"
    if not os.path.exists(ffolder):
        os.makedirs(ffolder)

    # Get filename in short
    my_filename = input_raster.split("/")[-1].split(".")[0]

    print(f"Splitting {my_filename} into {num_splits} subfiles:")

    with rasterio.open(input_raster) as dataset:
        width = dataset.width
        height = dataset.height

        # Get list of subrasters
        f_subrasters = []

        for i, (start, split_height) in enumerate(get_splits(height, num_splits)):
            window = windows.Window(0, start, width, split_height)
            transform = dataset.window_transform(window)

            profile = dataset.profile
            profile.update(
                {"height": window.height, "width": window.width, "transform": transform}
            )

            # Get filename
            f_subraster = f"{ffolder}/{my_filename}_subraster_{i}.tif"

            # Write raster
            with rasterio.open(
                f_subraster,
                "w",
                **profile,
            ) as dst:
                dst.write(dataset.read(window=window))

            # Attach filename to list
            f_subrasters.append(f_subraster)

    return f_subrasters

# %% [markdown]
# # 👉 User Input

# %%
# For subsetting
take_subset = False
subset_size = 1000

# For file selection
run_fast_files = False
run_slow_files = True

# For raster checks:
skip_raster_checks = True  # Directly load the raster info from the csv files
make_figures = False  # Takes 4 mins with plotting and 1.30 mins without

# %% [markdown]
# ## Load Coordinates and Data
#
# - Note that both, the coordinates and the .tif files are in the same CRS (EPSG:2154), so we can use the coordinates directly for extracting the data from the .tif files.

# %%
# Get site coordinates
site_coordinates = pd.read_csv("../00_process_nfi_data/nfi_final_sites_with_idp.csv")

# Take subset if needed
if take_subset:
    site_coordinates = site_coordinates.sample(subset_size, random_state=1)

# Display site coordinates
site_coordinates[:3]
# Out:
#        first_year  SiteID         x          y      idp           x_fr  \
# 34234        2015   34235 -1.716403  48.444659  1006445  351411.774387
# 11014        2013   11015  3.796458  46.427107   836253  761160.804953
# 15467        2010   15468  0.894015  44.987642   500357  534032.770425
#
#                y_fr
# 34234  6.826456e+06
# 11014  6.592213e+06
# 15467  6.434260e+06

# %%
# List all tiff files in agroparistech folder
files = sorted(glob.glob("../../data/raw/agroparistech/all_files/*.tif"))
files[:3]
# Out:
# ['../../data/raw/agroparistech/all_files/abal_distrib_v2016.tif',
#  '../../data/raw/agroparistech/all_files/abal_mortalite_v2018.tif',
#  '../../data/raw/agroparistech/all_files/acca_distrib_v2016.tif']

# %%
# Extract variables names from files
variables = [file.split("/")[-1].split(".")[0] for file in files]
variables[:3]
# Out:
# ['abal_distrib_v2016', 'abal_mortalite_v2018', 'acca_distrib_v2016']

# %%
# Merge files and variables
files_variables = pd.DataFrame({"files": files, "variables": variables})
files_variables[:3]
# Out:
#                                                files             variables
# 0  ../../data/raw/agroparistech/all_files/abal_di...    abal_distrib_v2016
# 1  ../../data/raw/agroparistech/all_files/abal_mo...  abal_mortalite_v2018
# 2  ../../data/raw/agroparistech/all_files/acca_di...    acca_distrib_v2016

# %%
# Define final df that will hold all data
df_coords = site_coordinates[["idp", "x_fr", "y_fr"]]
display(df_coords[:3])
df_coords.shape
# Out:
#            idp           x_fr          y_fr
# 34234  1006445  351411.774387  6.826456e+06
# 11014   836253  761160.804953  6.592213e+06
# 15467   500357  534032.770425  6.434260e+06
# (1000, 3)

# %%
# import geopandas as gpd
# import pandas as pd
# from shapely.geometry import Point

# # Create a GeoDataFrame from the df_coords
# gdf = gpd.GeoDataFrame(
#     df_coords,
#     geometry=[Point(xy) for xy in zip(df_coords.x_fr, df_coords.y_fr)],
#     crs="EPSG:2154",  # Set the coordinate reference system to RGF93 / Lambert-93 projection
# )

# # Export to Shapefile
# if take_subset:
#     gdf.to_file("agroparistech_qc_files/shapefile_for_subset.shp")
# else:
#     gdf.to_file("agroparistech_qc_files/shapefile.shp")

# %% [markdown]
# ## Attach Raster Information

# %%
# Loop through all files, open the raster, save an image of it, and attach the crs to the df

if not skip_raster_checks:
    for i in tqdm(range(files_variables.shape[0]), disable=False):
        # print(f" {i}. Working on {files_variables['variables'].iloc[i]}...")

        # Open raster
        raster = rasterio.open(files_variables["files"].iloc[i])

        # Load Image
        image = raster.read(1)

        # Turn into float to avoid error when putting values to NA
        image = image.astype(float)  # Convert to float

        # Get min value and CRS
        my_crs = raster.crs.to_string()
        my_na = np.min(image)

        # Attach CRS and min value to df
        files_variables = files_variables.copy()
        files_variables.at[i, "crs"] = my_crs
        files_variables.at[i, "na_value"] = my_na

        if make_figures:
            # Plot
            # Set minimum value to na
            image[image == np.min(image)] = np.nan
            # Add caption with the CRS and min value
            plt.figure(figsize=(8, 8))
            plt.imshow(image)
            plt.colorbar(fraction=0.046, pad=0.04)
            plt.title(f"{files_variables['variables'].iloc[i]}")
            plt.text(
                0,
                1300,
                f"Min Value: {my_na}\nCRS: {my_crs[:50]}...",
            )
            plt.savefig(
                f"agroparistech_qc_files/raster_{files_variables['variables'].iloc[i]}.png"
            )
            # plt.show()
            plt.close()

    # Check df
    display(files_variables.head(3))

    # Replace CRS with EPSG code
    for i in tqdm(range(files_variables.shape[0]), disable=False):
        if "RGF_1993_Lambert_Conformal" in files_variables["crs"].iloc[i]:
            files_variables.at[i, "crs"] = "EPSG:2154"

    display(files_variables.value_counts("crs"))

    # Save file
    files_variables.to_csv("agroparistech_qc_files/files_variables.csv", index=False)
    display(files_variables.head(3))
else:
    files_variables = pd.read_csv("agroparistech_qc_files/files_variables.csv")
    display(files_variables.head(3))
# Out:
#                                                files             variables  \
# 0  ../../data/raw/agroparistech/all_files/abal_di...    abal_distrib_v2016
# 1  ../../data/raw/agroparistech/all_files/abal_mo...  abal_mortalite_v2018
# 2  ../../data/raw/agroparistech/all_files/acca_di...    acca_distrib_v2016
#
#          crs      na_value
# 0  EPSG:2154 -3.402823e+38
# 1  EPSG:2154 -9.999000e+03
# 2  EPSG:2154 -3.402823e+38

# %% [markdown]
# ### Split fast and slow files

# %%
# These files are too big and take very long to extract
# So skipping them for now and will extract them separately
skip_these_files = [
    "tmoy_6190_et_v1",
    "tmoy_6190_hi_v1",
    "tmoy_6190_an_v1",
    "tmin_6190_hi_v1",
    "tmax_6190_et_v1",
    "rad_6190_et_v1",
    "rad_6190_an_v1",
    "etp_6190_et_v1",
    "etp_6190_an_v1",
    "bhctu_6190_et_v1",
    "bhctu_6190_an_v1",
    "ru_6190_et_v1",
    "ru_6190_an_v1",
]

files_variables_quick = files_variables[
    ~files_variables["variables"].isin(skip_these_files)
].reset_index(drop=True)

files_variables_slow = files_variables[
    files_variables["variables"].isin(skip_these_files)
].reset_index(drop=True)

print(f"Shape of files_variables_quick: {files_variables_quick.shape}")
for i in range(files_variables_quick.shape[0]):
    print(
        f" {i}. {files_variables_quick['variables'].iloc[i]:<20}\t{files_variables_quick['files'].iloc[i]}"
    )

display(f"Shape of files_variables_slow: {files_variables_slow.shape}")
for i in range(files_variables_slow.shape[0]):
    print(
        f" {i}. {files_variables_slow['variables'].iloc[i]:<20}\t{files_variables_slow['files'].iloc[i]}"
    )
# Out:
# Shape of files_variables_quick: (80, 4)
#  0. abal_distrib_v2016  	../../data/raw/agroparistech/all_files/abal_distrib_v2016.tif
#  1. abal_mortalite_v2018	../../data/raw/agroparistech/all_files/abal_mortalite_v2018.tif
#  2. acca_distrib_v2016  	../../data/raw/agroparistech/all_files/acca_distrib_v2016.tif
#  3. acca_mortalite_v2018	../../data/raw/agroparistech/all_files/acca_mortalite_v2018.tif
#  4. acmo_distrib_v2016  	../../data/raw/agroparistech/all_files/acmo_distrib_v2016.tif
#  5. acop_distrib_v2016  	../../data/raw/agroparistech/all_files/acop_distrib_v2016.tif
#  6. acpl_distrib_v2016  	../../data/raw/agroparistech/all_files/acpl_distrib_v2016.tif
#  7. acps_distrib_v2016  	../../data/raw/agroparistech/all_files/acps_distrib_v2016.tif
#  8. algl_distrib_v2016  	../../data/raw/agroparistech/all_files/algl_distrib_v2016.tif
#  9. bepe_distrib_v2016  	../../data/raw/agroparistech/all_files/bepe_distrib_v2016.tif
#  10. bepe_mortalite_v2018	../../data/raw/agroparistech/all_files/bepe_mortalite_v2018.tif
#  11. bepu_distrib_v2016  	../../data/raw/agroparistech/all_files/bepu_distrib_v2016.tif
#  12. cabe_distrib_v2016  	../../data/raw/agroparistech/all_files/cabe_distrib_v2016.tif
#  13. cabe_mortalite_v2018	../../data/raw/agroparistech/all_files/cabe_mortalite_v2018.tif
#  14. cas_59cl            	../../data/raw/agroparistech/all_files/cas_59cl.tif
#  15. casa_distrib_v2016  	../../data/raw/agroparistech/all_files/casa_distrib_v2016.tif
#  16. coav_mortalite_v2018	../../data/raw/agroparistech/all_files/coav_mortalite_v2018.tif
#  17. et_2014             	../../data/raw/agroparistech/all_files/et_2014.tif
#  18. fasy_distrib_v2016  	../../data/raw/agroparistech/all_files/fasy_distrib_v2016.tif
#  19. fasy_if_v2018       	../../data/raw/agroparistech/all_files/fasy_if_v2018.tif
#  20. fasy_mortalite_v2018	../../data/raw/agroparistech/all_files/fasy_mortalite_v2018.tif
#  21. fran_distrib_v2016  	../../data/raw/agroparistech/all_files/fran_distrib_v2016.tif
#  22. frex_distrib_v2016  	../../data/raw/agroparistech/all_files/frex_distrib_v2016.tif
#  23. laan_mortalite_v2018	../../data/raw/agroparistech/all_files/laan_mortalite_v2018.tif
#  24. lade_mortalite_v2018	../../data/raw/agroparistech/all_files/lade_mortalite_v2018.tif
#  25. masy_mortalite_v2018	../../data/raw/agroparistech/all_files/masy_mortalite_v2018.tif
#  26. ph_2008             	../../data/raw/agroparistech/all_files/ph_2008.tif
#  27. piab_distrib_v2016  	../../data/raw/agroparistech/all_files/piab_distrib_v2016.tif
#  28. piab_if_v2018       	../../data/raw/agroparistech/all_files/piab_if_v2018.tif
#  29. piab_mortalite_v2018	../../data/raw/agroparistech/all_files/piab_mortalite_v2018.tif
#  30. piha_distrib_v2016  	../../data/raw/agroparistech/all_files/piha_distrib_v2016.tif
#  31. pipi_mortalite_v2018	../../data/raw/agroparistech/all_files/pipi_mortalite_v2018.tif
#  32. pisi_mortalite_v2018	../../data/raw/agroparistech/all_files/pisi_mortalite_v2018.tif
#  33. pisy_distrib_v2016  	../../data/raw/agroparistech/all_files/pisy_distrib_v2016.tif
#  34. pisy_mortalite_v2018	../../data/raw/agroparistech/all_files/pisy_mortalite_v2018.tif
#  35. potr_mortalite_v2018	../../data/raw/agroparistech/all_files/potr_mortalite_v2018.tif
#  36. prav_distrib_v2016  	../../data/raw/agroparistech/all_files/prav_distrib_v2016.tif
#  37. prav_mortalite_v2018	../../data/raw/agroparistech/all_files/prav_mortalite_v2018.tif
#  38. prec_6190_an_v1     	../../data/raw/agroparistech/all_files/prec_6190_an_v1.tif
#  39. prec_6190_et_v1     	../../data/raw/agroparistech/all_files/prec_6190_et_v1.tif
#  40. prob_mort_epi       	../../data/raw/agroparistech/all_files/prob_mort_epi.tif
#  41. prob_mort_sap       	../../data/raw/agroparistech/all_files/prob_mort_sap.tif
#  42. psme_mortalite_v2018	../../data/raw/agroparistech/all_files/psme_mortalite_v2018.tif
#  43. quil_distrib_v2016  	../../data/raw/agroparistech/all_files/quil_distrib_v2016.tif
#  44. quil_mortalite_v2018	../../data/raw/agroparistech/all_files/quil_mortalite_v2018.tif
#  45. qupe_distrib_v2016  	../../data/raw/agroparistech/all_files/qupe_distrib_v2016.tif
#  46. qupe_mortalite_v2018	../../data/raw/agroparistech/all_files/qupe_mortalite_v2018.tif
#  47. qupu_distrib_v2016  	../../data/raw/agroparistech/all_files/qupu_distrib_v2016.tif
#  48. qupu_mortalite_v2018	../../data/raw/agroparistech/all_files/qupu_mortalite_v2018.tif
#  49. qupy_mortalite_v2018	../../data/raw/agroparistech/all_files/qupy_mortalite_v2018.tif
#  50. quro_distrib_v2016  	../../data/raw/agroparistech/all_files/quro_distrib_v2016.tif
#  51. quro_mortalite_v2018	../../data/raw/agroparistech/all_files/quro_mortalite_v2018.tif
#  52. rops_distrib_v2016  	../../data/raw/agroparistech/all_files/rops_distrib_v2016.tif
#  53. rops_mortalite_v2018	../../data/raw/agroparistech/all_files/rops_mortalite_v2018.tif
#  54. rr61858610_13       	../../data/raw/agroparistech/all_files/rr61858610_13.tif
#  55. rr61858610_et       	../../data/raw/agroparistech/all_files/rr61858610_et.tif
#  56. rum_500_v2009       	../../data/raw/agroparistech/all_files/rum_500_v2009.tif
#  57. saal_distrib_v2016  	../../data/raw/agroparistech/all_files/saal_distrib_v2016.tif
#  58. saal_mortalite_v2018	../../data/raw/agroparistech/all_files/saal_mortalite_v2018.tif
#  59. saca_distrib_v2016  	../../data/raw/agroparistech/all_files/saca_distrib_v2016.tif
#  60. saca_mortalite_v2018	../../data/raw/agroparistech/all_files/saca_mortalite_v2018.tif
#  61. saci_distrib_v2016  	../../data/raw/agroparistech/all_files/saci_distrib_v2016.tif
#  62. soar_distrib_v2016  	../../data/raw/agroparistech/all_files/soar_distrib_v2016.tif
#  63. soau_distrib_v2016  	../../data/raw/agroparistech/all_files/soau_distrib_v2016.tif
#  64. soau_mortalite_v2018	../../data/raw/agroparistech/all_files/soau_mortalite_v2018.tif
#  65. soto_distrib_v2016  	../../data/raw/agroparistech/all_files/soto_distrib_v2016.tif
#  66. soto_mortalite_v2018	../../data/raw/agroparistech/all_files/soto_mortalite_v2018.tif
#  67. tico_distrib_v2016  	../../data/raw/agroparistech/all_files/tico_distrib_v2016.tif
#  68. tipl_distrib_v2016  	../../data/raw/agroparistech/all_files/tipl_distrib_v2016.tif
#  69. tm61858610_13       	../../data/raw/agroparistech/all_files/tm61858610_13.tif
#  70. tm61858610_et       	../../data/raw/agroparistech/all_files/tm61858610_et.tif
#  71. tm61858610_hi       	../../data/raw/agroparistech/all_files/tm61858610_hi.tif
#  72. tn61858610_13       	../../data/raw/agroparistech/all_files/tn61858610_13.tif
#  73. tn61858610_et       	../../data/raw/agroparistech/all_files/tn61858610_et.tif
#  74. tn61858610_hi       	../../data/raw/agroparistech/all_files/tn61858610_hi.tif
#  75. tx61858610_13       	../../data/raw/agroparistech/all_files/tx61858610_13.tif
#  76. tx61858610_et       	../../data/raw/agroparistech/all_files/tx61858610_et.tif
#  77. tx61858610_hi       	../../data/raw/agroparistech/all_files/tx61858610_hi.tif
#  78. ulgl_distrib_v2016  	../../data/raw/agroparistech/all_files/ulgl_distrib_v2016.tif
#  79. ulmi_distrib_v2016  	../../data/raw/agroparistech/all_files/ulmi_distrib_v2016.tif
# 'Shape of files_variables_slow: (13, 4)'
#  0. bhctu_6190_an_v1    	../../data/raw/agroparistech/all_files/bhctu_6190_an_v1.tif
#  1. bhctu_6190_et_v1    	../../data/raw/agroparistech/all_files/bhctu_6190_et_v1.tif
#  2. etp_6190_an_v1      	../../data/raw/agroparistech/all_files/etp_6190_an_v1.tif
#  3. etp_6190_et_v1      	../../data/raw/agroparistech/all_files/etp_6190_et_v1.tif
#  4. rad_6190_an_v1      	../../data/raw/agroparistech/all_files/rad_6190_an_v1.tif
#  5. rad_6190_et_v1      	../../data/raw/agroparistech/all_files/rad_6190_et_v1.tif
#  6. ru_6190_an_v1       	../../data/raw/agroparistech/all_files/ru_6190_an_v1.tif
#  7. ru_6190_et_v1       	../../data/raw/agroparistech/all_files/ru_6190_et_v1.tif
#  8. tmax_6190_et_v1     	../../data/raw/agroparistech/all_files/tmax_6190_et_v1.tif
#  9. tmin_6190_hi_v1     	../../data/raw/agroparistech/all_files/tmin_6190_hi_v1.tif
#  10. tmoy_6190_an_v1     	../../data/raw/agroparistech/all_files/tmoy_6190_an_v1.tif
#  11. tmoy_6190_et_v1     	../../data/raw/agroparistech/all_files/tmoy_6190_et_v1.tif
#  12. tmoy_6190_hi_v1     	../../data/raw/agroparistech/all_files/tmoy_6190_hi_v1.tif

# %% [markdown]
# ### Fast Files

# %%
if run_fast_files:
    # Add groupings, make sure that slow variables are split to own cores
    files_variables_quick = files_variables_quick.copy()
    files_variables_quick["group"] = np.arange(len(files_variables_quick)) % 10 + 1

    # Create list of df to be passed to multiprocessing
    grouped = files_variables_quick.groupby("group")
    df_list = [group for name, group in grouped]

    # Display one group
    df_list[0].head(3)

# %%
if run_fast_files:
    pass
    # Test on one group
    # df_test = parallel_agroparistech_extraction(df_list[0], df_coords, progress_bar=False)
    # df_test = df_test.copy()

    # # Print shape
    # df_test.shape

    # # Replace NA values
    # df_test = clean_na_in_agroparistech(df_test, files_variables_quick)

    # # Final display
    # display(df_test.head(3))
    # display(df_test.tail(3))

# %%
if run_fast_files:
    # Run in parallel
    df_quick = run_mp(
        parallel_agroparistech_extraction,
        df_list,
        progress_bar=True,
        num_cores=10,
        df_coords=df_coords,
        verbose=False,
    )

    # Combine the list of dataframes using list comprehension
    df_quick_merged = df_quick[0]
    for i in range(1, len(df_quick)):
        df_quick_merged = pd.merge(
            df_quick_merged, df_quick[i], on=["idp", "y_fr", "x_fr"], how="left"
        )

    # Replace faulty NA values
    df_quick_merged = clean_na_in_agroparistech(df_quick_merged, files_variables_quick)

    # Display final df
    display(df_quick_merged)

    # Notify me when done
    chime.success()

# %%
if run_fast_files:
    # Cleaning df
    df_quick_merged = df_quick_merged.drop(
        columns=["x_fr", "y_fr"]
    )  # remove coordinates
    df_quick_merged = df_quick_merged.reindex(
        sorted(df_quick_merged.columns), axis=1
    )  # sort alphabetically
    df_quick_merged.insert(
        0, "idp", df_quick_merged.pop("idp")
    )  # move idp to first again

    print(f"Final columns in df_quick_merged:")
    for i in range(df_quick_merged.shape[1]):
        print(f" {i}. {df_quick_merged.columns[i]}")

# %%
if run_fast_files:
    # Save it
    if take_subset:
        df_quick_merged.to_feather(
            "data_agroparistech_fastfiles_before_qc_subset.feather"
        )
    else:
        df_quick_merged.to_feather("data_agroparistech_fastfiles_before_qc.feather")

# %% [markdown]
# ❌ TODO: Subset needs filtering of NA values, probably setting just to zero but not really sure...

# %% [markdown]
# ### Slow Files (large rasters)
#
# - The parallelization for the large raster files is to split the locations into 10 groups and then run the function on one tif file in parallel.

# %%
for slow_file in files_variables_slow["files"]:
    slow_var = slow_file.split("/")[-1].split(".")[0]
    print(slow_file, slow_var)
# Out:
# ../../data/raw/agroparistech/all_files/bhctu_6190_an_v1.tif bhctu_6190_an_v1
# ../../data/raw/agroparistech/all_files/bhctu_6190_et_v1.tif bhctu_6190_et_v1
# ../../data/raw/agroparistech/all_files/etp_6190_an_v1.tif etp_6190_an_v1
# ../../data/raw/agroparistech/all_files/etp_6190_et_v1.tif etp_6190_et_v1
# ../../data/raw/agroparistech/all_files/rad_6190_an_v1.tif rad_6190_an_v1
# ../../data/raw/agroparistech/all_files/rad_6190_et_v1.tif rad_6190_et_v1
# ../../data/raw/agroparistech/all_files/ru_6190_an_v1.tif ru_6190_an_v1
# ../../data/raw/agroparistech/all_files/ru_6190_et_v1.tif ru_6190_et_v1
# ../../data/raw/agroparistech/all_files/tmax_6190_et_v1.tif tmax_6190_et_v1
# ../../data/raw/agroparistech/all_files/tmin_6190_hi_v1.tif tmin_6190_hi_v1
# ../../data/raw/agroparistech/all_files/tmoy_6190_an_v1.tif tmoy_6190_an_v1
# ../../data/raw/agroparistech/all_files/tmoy_6190_et_v1.tif tmoy_6190_et_v1
# ../../data/raw/agroparistech/all_files/tmoy_6190_hi_v1.tif tmoy_6190_hi_v1

# %%
i = 0
slow_file = files_variables_slow["files"].iloc[i]
slow_var = files_variables_slow["variables"].iloc[i]
slow_file
# Out:
# '../../data/raw/agroparistech/all_files/bhctu_6190_an_v1.tif'

# %%
# Split the raster into smaller files
max_mb = 5

# Do
input_raster = slow_file
current_subraster_files = split_raster(
    input_raster, "agroparistech_qc_files", max_mb=max_mb
)
df_subraster = pd.DataFrame({"files": current_subraster_files, "variables": slow_var})
df_subraster
# Out:
# Splitting bhctu_6190_an_v1 into 183 subfiles:
#                                                  files        variables
# 0    agroparistech_qc_files/subrasters/bhctu_6190_a...  tmoy_6190_hi_v1
# 1    agroparistech_qc_files/subrasters/bhctu_6190_a...  tmoy_6190_hi_v1
# 2    agroparistech_qc_files/subrasters/bhctu_6190_a...  tmoy_6190_hi_v1
# 3    agroparistech_qc_files/subrasters/bhctu_6190_a...  tmoy_6190_hi_v1
# 4    agroparistech_qc_files/subrasters/bhctu_6190_a...  tmoy_6190_hi_v1
# ..                                                 ...              ...
# 178  agroparistech_qc_files/subrasters/bhctu_6190_a...  tmoy_6190_hi_v1
# 179  agroparistech_qc_files/subrasters/bhctu_6190_a...  tmoy_6190_hi_v1
# 180  agroparistech_qc_files/subrasters/bhctu_6190_a...  tmoy_6190_hi_v1
# 181  agroparistech_qc_files/subrasters/bhctu_6190_a...  tmoy_6190_hi_v1
# 182  agroparistech_qc_files/subrasters/bhctu_6190_a...  tmoy_6190_hi_v1
#
# [183 rows x 2 columns]

# %%
df_subraster["crs"] = files_variables.query("variables == @slow_var")["crs"].iloc[0]
df_subraster["na_value"] = files_variables.query("variables == @slow_var")[
    "na_value"
].iloc[0]

# %%
# Add groupings, make sure that slow variables are split to own cores
df_subraster = df_subraster.copy()
df_subraster["group"] = np.arange(len(df_subraster)) % 10 + 1

display(df_subraster)

# Create list of df to be passed to multiprocessing
grouped = df_subraster.groupby("group")
df_list = [group for name, group in grouped]

# Display one group
display(df_list[0].head(3))
df_list[0].shape
# Out:
#                                                  files        variables  \
# 0    agroparistech_qc_files/subrasters/bhctu_6190_a...  tmoy_6190_hi_v1
# 1    agroparistech_qc_files/subrasters/bhctu_6190_a...  tmoy_6190_hi_v1
# 2    agroparistech_qc_files/subrasters/bhctu_6190_a...  tmoy_6190_hi_v1
# 3    agroparistech_qc_files/subrasters/bhctu_6190_a...  tmoy_6190_hi_v1
# 4    agroparistech_qc_files/subrasters/bhctu_6190_a...  tmoy_6190_hi_v1
# ..                                                 ...              ...
# 178  agroparistech_qc_files/subrasters/bhctu_6190_a...  tmoy_6190_hi_v1
# 179  agroparistech_qc_files/subrasters/bhctu_6190_a...  tmoy_6190_hi_v1
# 180  agroparistech_qc_files/subrasters/bhctu_6190_a...  tmoy_6190_hi_v1
# 181  agroparistech_qc_files/subrasters/bhctu_6190_a...  tmoy_6190_hi_v1
# 182  agroparistech_qc_files/subrasters/bhctu_6190_a...  tmoy_6190_hi_v1
#
#            crs      na_value  group
# 0    EPSG:2154 -3.402823e+38      1
# 1    EPSG:2154 -3.402823e+38      2
# 2    EPSG:2154 -3.402823e+38      3
# 3    EPSG:2154 -3.402823e+38      4
# 4    EPSG:2154 -3.402823e+38      5
# ..         ...           ...    ...
# 178  EPSG:2154 -3.402823e+38      9
# 179  EPSG:2154 -3.402823e+38     10
# 180  EPSG:2154 -3.402823e+38      1
# 181  EPSG:2154 -3.402823e+38      2
# 182  EPSG:2154 -3.402823e+38      3
#
# [183 rows x 5 columns]
#                                                 files        variables  \
# 0   agroparistech_qc_files/subrasters/bhctu_6190_a...  tmoy_6190_hi_v1
# 10  agroparistech_qc_files/subrasters/bhctu_6190_a...  tmoy_6190_hi_v1
# 20  agroparistech_qc_files/subrasters/bhctu_6190_a...  tmoy_6190_hi_v1
#
#           crs      na_value  group
# 0   EPSG:2154 -3.402823e+38      1
# 10  EPSG:2154 -3.402823e+38      1
# 20  EPSG:2154 -3.402823e+38      1
# (19, 5)

# %%
# Test on one group
df_test = parallel_agroparistech_extraction(
    df_list[9], df_coords, progress_bar=False, concat_by_axis=0
)
df_test = df_test.copy()

# Print shape
df_test.shape
df_test
# Out:
# Group 10 	 | 1/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_9.tif
# Group 10 	 | 2/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_19.tif
# Group 10 	 | 3/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_29.tif
# Group 10 	 | 4/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_39.tif
# Group 10 	 | 5/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_49.tif
# Group 10 	 | 6/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_59.tif
# Group 10 	 | 7/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_69.tif
# Group 10 	 | 8/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_79.tif
# Group 10 	 | 9/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_89.tif
# Group 10 	 | 10/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_99.tif
# Group 10 	 | 11/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_109.tif
# Group 10 	 | 12/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_119.tif
# Group 10 	 | 13/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_129.tif
# Group 10 	 | 14/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_139.tif
# Group 10 	 | 15/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_149.tif
# Group 10 	 | 16/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_159.tif
# Group 10 	 | 17/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_169.tif
# Group 10 	 | 18/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_179.tif
#    tmoy_6190_hi_v1          y_fr           x_fr        idp
# 0        -4.924745  6.708830e+06  558298.454808  1029396.0
# 1        70.367752  6.591881e+06  917030.559170  1028340.0
# 2       -11.155251  6.297802e+06  841579.530018   536407.0

# %%
df_long = pd.DataFrame()
counter = 0
for xxx in df_list:
    # Test on one group
    df_test = parallel_agroparistech_extraction(
        xxx, df_coords, progress_bar=False, concat_by_axis=0
    )

    df_test = df_test.copy()
    df_long = pd.concat([df_long, df_test], axis=0)

    counter = counter + df_test.shape[0]
display(counter)
display(df_long.shape)
display(df_long.drop_duplicates()z.shape)
# Out:
# Group 1 	 | 1/19 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_0.tif
# Group 1 	 | 2/19 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_10.tif
# Group 1 	 | 3/19 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_20.tif
# Group 1 	 | 4/19 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_30.tif
# Group 1 	 | 5/19 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_40.tif
# Group 1 	 | 6/19 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_50.tif
# Group 1 	 | 7/19 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_60.tif
# Group 1 	 | 8/19 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_70.tif
# Group 1 	 | 9/19 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_80.tif
# Group 1 	 | 10/19 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_90.tif
# Group 1 	 | 11/19 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_100.tif
# Group 1 	 | 12/19 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_110.tif
# Group 1 	 | 13/19 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_120.tif
# Group 1 	 | 14/19 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_130.tif
# Group 1 	 | 15/19 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_140.tif
# Group 1 	 | 16/19 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_150.tif
# Group 1 	 | 17/19 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_160.tif
# Group 1 	 | 18/19 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_170.tif
# Group 1 	 | 19/19 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_180.tif
# Group 2 	 | 1/19 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_1.tif
# Group 2 	 | 2/19 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_11.tif
# Group 2 	 | 3/19 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_21.tif
# Group 2 	 | 4/19 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_31.tif
# Group 2 	 | 5/19 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_41.tif
# Group 2 	 | 6/19 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_51.tif
# Group 2 	 | 7/19 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_61.tif
# Group 2 	 | 8/19 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_71.tif
# Group 2 	 | 9/19 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_81.tif
# Group 2 	 | 10/19 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_91.tif
# Group 2 	 | 11/19 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_101.tif
# Group 2 	 | 12/19 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_111.tif
# Group 2 	 | 13/19 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_121.tif
# Group 2 	 | 14/19 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_131.tif
# Group 2 	 | 15/19 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_141.tif
# Group 2 	 | 16/19 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_151.tif
# Group 2 	 | 17/19 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_161.tif
# Group 2 	 | 18/19 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_171.tif
# Group 2 	 | 19/19 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_181.tif
# Group 3 	 | 1/19 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_2.tif
# Group 3 	 | 2/19 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_12.tif
# Group 3 	 | 3/19 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_22.tif
# Group 3 	 | 4/19 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_32.tif
# Group 3 	 | 5/19 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_42.tif
# Group 3 	 | 6/19 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_52.tif
# Group 3 	 | 7/19 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_62.tif
# Group 3 	 | 8/19 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_72.tif
# Group 3 	 | 9/19 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_82.tif
# Group 3 	 | 10/19 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_92.tif
# Group 3 	 | 11/19 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_102.tif
# Group 3 	 | 12/19 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_112.tif
# Group 3 	 | 13/19 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_122.tif
# Group 3 	 | 14/19 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_132.tif
# Group 3 	 | 15/19 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_142.tif
# Group 3 	 | 16/19 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_152.tif
# Group 3 	 | 17/19 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_162.tif
# Group 3 	 | 18/19 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_172.tif
# Group 3 	 | 19/19 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_182.tif
# Group 4 	 | 1/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_3.tif
# Group 4 	 | 2/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_13.tif
# Group 4 	 | 3/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_23.tif
# Group 4 	 | 4/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_33.tif
# Group 4 	 | 5/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_43.tif
# Group 4 	 | 6/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_53.tif
# Group 4 	 | 7/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_63.tif
# Group 4 	 | 8/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_73.tif
# Group 4 	 | 9/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_83.tif
# Group 4 	 | 10/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_93.tif
# Group 4 	 | 11/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_103.tif
# Group 4 	 | 12/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_113.tif
# Group 4 	 | 13/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_123.tif
# Group 4 	 | 14/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_133.tif
# Group 4 	 | 15/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_143.tif
# Group 4 	 | 16/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_153.tif
# Group 4 	 | 17/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_163.tif
# Group 4 	 | 18/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_173.tif
# Group 5 	 | 1/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_4.tif
# Group 5 	 | 2/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_14.tif
# Group 5 	 | 3/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_24.tif
# Group 5 	 | 4/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_34.tif
# Group 5 	 | 5/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_44.tif
# Group 5 	 | 6/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_54.tif
# Group 5 	 | 7/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_64.tif
# Group 5 	 | 8/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_74.tif
# Group 5 	 | 9/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_84.tif
# Group 5 	 | 10/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_94.tif
# Group 5 	 | 11/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_104.tif
# Group 5 	 | 12/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_114.tif
# Group 5 	 | 13/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_124.tif
# Group 5 	 | 14/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_134.tif
# Group 5 	 | 15/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_144.tif
# Group 5 	 | 16/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_154.tif
# Group 5 	 | 17/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_164.tif
# Group 5 	 | 18/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_174.tif
# Group 6 	 | 1/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_5.tif
# Group 6 	 | 2/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_15.tif
# Group 6 	 | 3/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_25.tif
# Group 6 	 | 4/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_35.tif
# Group 6 	 | 5/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_45.tif
# Group 6 	 | 6/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_55.tif
# Group 6 	 | 7/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_65.tif
# Group 6 	 | 8/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_75.tif
# Group 6 	 | 9/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_85.tif
# Group 6 	 | 10/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_95.tif
# Group 6 	 | 11/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_105.tif
# Group 6 	 | 12/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_115.tif
# Group 6 	 | 13/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_125.tif
# Group 6 	 | 14/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_135.tif
# Group 6 	 | 15/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_145.tif
# Group 6 	 | 16/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_155.tif
# Group 6 	 | 17/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_165.tif
# Group 6 	 | 18/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_175.tif
# Group 7 	 | 1/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_6.tif
# Group 7 	 | 2/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_16.tif
# Group 7 	 | 3/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_26.tif
# Group 7 	 | 4/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_36.tif
# Group 7 	 | 5/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_46.tif
# Group 7 	 | 6/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_56.tif
# Group 7 	 | 7/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_66.tif
# Group 7 	 | 8/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_76.tif
# Group 7 	 | 9/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_86.tif
# Group 7 	 | 10/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_96.tif
# Group 7 	 | 11/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_106.tif
# Group 7 	 | 12/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_116.tif
# Group 7 	 | 13/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_126.tif
# Group 7 	 | 14/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_136.tif
# Group 7 	 | 15/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_146.tif
# Group 7 	 | 16/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_156.tif
# Group 7 	 | 17/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_166.tif
# Group 7 	 | 18/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_176.tif
# Group 8 	 | 1/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_7.tif
# Group 8 	 | 2/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_17.tif
# Group 8 	 | 3/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_27.tif
# Group 8 	 | 4/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_37.tif
# Group 8 	 | 5/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_47.tif
# Group 8 	 | 6/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_57.tif
# Group 8 	 | 7/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_67.tif
# Group 8 	 | 8/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_77.tif
# Group 8 	 | 9/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_87.tif
# Group 8 	 | 10/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_97.tif
# Group 8 	 | 11/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_107.tif
# Group 8 	 | 12/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_117.tif
# Group 8 	 | 13/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_127.tif
# Group 8 	 | 14/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_137.tif
# Group 8 	 | 15/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_147.tif
# Group 8 	 | 16/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_157.tif
# Group 8 	 | 17/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_167.tif
# Group 8 	 | 18/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_177.tif
# Group 9 	 | 1/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_8.tif
# Group 9 	 | 2/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_18.tif
# Group 9 	 | 3/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_28.tif
# Group 9 	 | 4/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_38.tif
# Group 9 	 | 5/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_48.tif
# Group 9 	 | 6/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_58.tif
# Group 9 	 | 7/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_68.tif
# Group 9 	 | 8/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_78.tif
# Group 9 	 | 9/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_88.tif
# Group 9 	 | 10/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_98.tif
# Group 9 	 | 11/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_108.tif
# Group 9 	 | 12/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_118.tif
# Group 9 	 | 13/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_128.tif
# Group 9 	 | 14/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_138.tif
# Group 9 	 | 15/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_148.tif
# Group 9 	 | 16/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_158.tif
# Group 9 	 | 17/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_168.tif
# Group 9 	 | 18/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_178.tif
# Group 10 	 | 1/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_9.tif
# Group 10 	 | 2/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_19.tif
# Group 10 	 | 3/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_29.tif
# Group 10 	 | 4/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_39.tif
# Group 10 	 | 5/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_49.tif
# Group 10 	 | 6/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_59.tif
# Group 10 	 | 7/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_69.tif
# Group 10 	 | 8/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_79.tif
# Group 10 	 | 9/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_89.tif
# Group 10 	 | 10/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_99.tif
# Group 10 	 | 11/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_109.tif
# Group 10 	 | 12/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_119.tif
# Group 10 	 | 13/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_129.tif
# Group 10 	 | 14/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_139.tif
# Group 10 	 | 15/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_149.tif
# Group 10 	 | 16/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_159.tif
# Group 10 	 | 17/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_169.tif
# Group 10 	 | 18/18 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/bhctu_6190_an_v1_subraster_179.tif
# 50
# (50, 4)
# (25, 4)

# %%
df_long
# Out:
#    tmoy_6190_hi_v1          y_fr           x_fr        idp
# 0         2.642760  6.910495e+06  701897.537075   503318.0
# 1        -0.292560  6.591881e+06  917030.559170  1028340.0
# 2         4.139030  6.396748e+06  599657.796498   541626.0
# 0         2.642760  6.910495e+06  701897.537075   503318.0
# 1         1.074437  6.520442e+06  622672.053320   543583.0
# 0         4.470612  6.902237e+06  493946.738191   523317.0
# 1         4.427735  6.708830e+06  558298.454808  1029396.0
# 2         5.407806  6.448577e+06  494188.651034   507110.0
# 3         6.832966  6.253610e+06  392680.783305   549519.0
# 0         3.871207  6.631091e+06  653575.130239   776711.0
# 0         5.965383  6.297802e+06  841579.530018   536407.0
# 0         3.836348  6.872521e+06  461720.609202   952852.0
# 1         5.278198  6.811858e+06  303323.935232   543233.0
# 2         1.467515  6.550285e+06  756808.709307   861281.0
# 3         5.288727  6.486689e+06  476520.463600   557414.0
# 4         7.290113  6.295776e+06  367053.901173   506741.0
# 5         5.965383  6.297802e+06  841579.530018   536407.0
# 0         1.945311  6.804257e+06  854899.804190   500804.0
# 1         1.606741  6.544342e+06  750763.432895   558607.0
# 2         1.843018  6.483535e+06  734262.560838   524337.0
# 3         6.737490  6.351698e+06  369510.023884   517514.0
# 4         3.668332  6.284719e+06  969333.454509   535497.0
# 5         4.834705  6.220302e+06  434361.464476   529590.0
# 0         3.415206  6.796657e+06  451101.757358   558756.0
# 1         5.676897  6.732936e+06  422596.273732   549017.0
# 2         5.061691  6.540572e+06  484958.940261   530269.0
# 3         2.992300  6.345306e+06  893932.645519   548964.0
# 4         3.668332  6.284719e+06  969333.454509   535497.0
# 5         4.834705  6.220302e+06  434361.464476   529590.0

# %%
# Test on one group
df_test = parallel_agroparistech_extraction(
    df_list[9], df_coords, progress_bar=False, concat_by_axis=0
)
df_test = df_test.copy()

# Print shape
df_test.shape
df_test
# Out:
# Group 10 	 | 1/16 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/tmoy_6190_hi_v1_subraster_9.tif
# Group 10 	 | 2/16 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/tmoy_6190_hi_v1_subraster_19.tif
# Group 10 	 | 3/16 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/tmoy_6190_hi_v1_subraster_29.tif
# Group 10 	 | 4/16 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/tmoy_6190_hi_v1_subraster_39.tif
# Group 10 	 | 5/16 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/tmoy_6190_hi_v1_subraster_49.tif
# Group 10 	 | 6/16 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/tmoy_6190_hi_v1_subraster_59.tif
# Group 10 	 | 7/16 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/tmoy_6190_hi_v1_subraster_69.tif
# Group 10 	 | 8/16 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/tmoy_6190_hi_v1_subraster_79.tif
# Group 10 	 | 9/16 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/tmoy_6190_hi_v1_subraster_89.tif
# Group 10 	 | 10/16 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/tmoy_6190_hi_v1_subraster_99.tif
# Group 10 	 | 11/16 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/tmoy_6190_hi_v1_subraster_109.tif
# Group 10 	 | 12/16 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/tmoy_6190_hi_v1_subraster_119.tif
# Group 10 	 | 13/16 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/tmoy_6190_hi_v1_subraster_129.tif
# Group 10 	 | 14/16 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/tmoy_6190_hi_v1_subraster_139.tif
# Group 10 	 | 15/16 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/tmoy_6190_hi_v1_subraster_149.tif
# Group 10 	 | 16/16 | tmoy_6190_hi_v1.tif | EPSG:2154 | agroparistech_qc_files/subrasters/tmoy_6190_hi_v1_subraster_159.tif
#    tmoy_6190_hi_v1          y_fr           x_fr       idp
# 0         3.415206  6.796657e+06  451101.757358  558756.0
# 1         5.676897  6.732936e+06  422596.273732  549017.0
# 2         5.061691  6.540572e+06  484958.940261  530269.0
# 3         2.992300  6.345306e+06  893932.645519  548964.0

# %%
# Replace NA values
df_test = clean_na_in_agroparistech(df_test, df_subraster)

# Final display
display(df_test.head(3))
display(df_test.tail(3))

# %%
# Run in parallel
df_mp = run_mp(
    parallel_agroparistech_extraction,
    df_list,
    progress_bar=True,
    num_cores=10,
    df_coords=df_coords,
    verbose=False,
    concat_by_axis=0,
)

# Combine the list of dataframes using list comprehension
df_mp_merged = df_mp[0]
for i in range(1, len(df_mp)):
    df_mp_merged = pd.merge(
        df_mp_merged, df_mp[i], on=["idp", "y_fr", "x_fr"], how="left"
    )

# Replace faulty NA values
df_mp_merged = clean_na_in_agroparistech(df_mp_merged, files_variables_quick)

# Display final df
display(df_mp_merged)

# Notify me when done
chime.success()
# Out:
# 100%|██████████| 10/10 [00:08<00:00,  1.25it/s]
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ---

# %%
# df_coords_groups = df_coords.copy()
# df_coords_groups["group"] = np.arange(len(df_coords_groups)) % 10 + 1
# grouped = df_coords_groups.groupby("group")
# df_list = [group.reset_index(drop=True) for name, group in grouped]

# %%
# # Testing one group for one file
# my_file = files_variables_slow.iloc[0]["files"]
# my_var = files_variables_slow.iloc[0]["variables"]
# my_df = df_list[0]

# wrapper_for_large_files(my_df, my_file, my_var, progress_bar=True)

# %%
# %%time
# # Test on one group for all files

# df_slow_i = run_mp(
#     wrapper_for_large_files,
#     df_list,
#     # combine_func=pd.concat,
#     num_cores=10,
#     tif_in = files_variables_slow.iloc[0]["files"],
#     var_in = files_variables_slow.iloc[0]["variables"],
#     progress_bar=False
# )
# # Combine the list of dataframes using list comprehension
# df_slow = df_slow_i
# df_slow_merged = df_slow[0]
# for i in range(1, len(df_slow)):
#     df_slow_merged = pd.concat([df_slow_merged, df_slow[i]], axis=0)

# df_slow_merged

# %%
# # Run in parallel for all groups and all files

# df_slow_fin = pd.DataFrame(
#     {"idp": df_coords["idp"], "x_fr": df_coords["x_fr"], "y_fr": df_coords["y_fr"]}
# )

# for f, v in zip(files_variables_slow["files"], files_variables_slow["variables"]):
#     print(f"Extracting {v}")

#     df_slow_i = run_mp(
#         wrapper_for_large_files,
#         df_list,
#         # combine_func=pd.concat,
#         progress_bar=True,
#         num_cores=10,
#         tif_in=f,
#         var_in=v,
#     )

#     df_slow = df_slow_i
#     df_slow_merged = df_slow[0]
#     for i in range(1, len(df_slow)):
#         df_slow_merged = pd.concat([df_slow_merged, df_slow[i]], axis=0).drop(
#             columns=["group"]
#         )

#     # display(df_slow_merged)

#     df_slow_fin = pd.merge(
#         df_slow_0, width
# chime.success()
# Out:
# Extracting bhctu_6190_an_v1
#   0%|          | 0/10 [32:36<?, ?it/s]

# %%
# # Quick Visual Check
# df_slow_fin

# %%
# # Save it
# df_slow_fin.to_feather("data_agroparistech_slowfiles_before_qc.feather")
# df_slow_fin.to_csv("data_agroparistech_slowfiles_before_qc.csv", index=False)

# %% [markdown]
# ---

# %%
# Add groupings, make sure that slow variables are split to own cores
files_variables_slow["group"] = np.arange(len(files_variables_slow)) % 10 + 1

# Create list of df to be passed to multiprocessing
grouped = files_variables_slow.groupby("group")
df_list = [group for name, group in grouped]
# Out:
# /var/folders/39/534x_msj7sl1kcxj2mg109x40000gn/T/ipykernel_23839/2808177653.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   files_variables_slow["group"] = np.arange(len(files_variables_slow)) % 10 + 1

# %%
# Run in parallel
df_slow = run_mp(
    parallel_raster_extraction,
    df_list,
    progress_bar=True,
    num_cores=10,
    df_coords=df_coords,
    verbose=False,
)
# chime.success()
# Out:
#   0%|          | 0/10 [6:21:03<?, ?it/s]

# %%
# Combine the list of dataframes using list comprehension
df_slow_merged = df_slow[0]
for i in range(1, len(df_slow)):
    df_slow_merged = pd.merge(
        df_slow_merged, df_slow[i], on=["idp", "y_fr", "x_fr"], how="left"
    )

# %%
# Quick Visual Check
df_slow_merged
# Out:
#            idp          x_fr          y_fr  abal_distrib_v2016  \
# 0       632691  2.674150e+05  6.820144e+06            0.116299
# 1       702597  7.269712e+05  6.566524e+06            0.085622
# 2       706240  7.275625e+05  6.636462e+06            0.051618
# 3       708321  5.070276e+05  6.792198e+06            0.040013
# 4       708369  9.810095e+05  6.248657e+06            0.000747
# ...        ...           ...           ...                 ...
# 40017  1131396  7.284673e+05  6.743375e+06            0.045600
# 40018  1131409  6.307829e+05  6.176717e+06            0.473966
# 40019  1131410  1.030439e+06  6.764769e+06            0.049305
# 40020  1131424  7.597461e+05  6.425373e+06            0.607617
# 40021  1131437  7.317198e+05  6.655412e+06            0.116348
#
#        bepe_mortalite_v2018  fasy_mortalite_v2018  piha_distrib_v2016  \
# 0                 -0.006745              0.003381        1.317830e-10
# 1              -9999.000000          -9999.000000        2.808699e-08
# 2              -9999.000000              0.003246        1.679225e-06
# 3                 -0.006780              0.003302        5.390015e-06
# 4              -9999.000000          -9999.000000        1.169433e-02
# ...                     ...                   ...                 ...
# 40017             -0.006766          -9999.000000        2.963565e-06
# 40018          -9999.000000              0.004199        2.519738e-13
# 40019          -9999.000000          -9999.000000        5.670998e-06
# 40020          -9999.000000              0.002793        4.454063e-13
# 40021          -9999.000000              0.003179        7.465844e-08
#
#        prob_mort_epi  quro_distrib_v2016  saca_mortalite_v2018  ...  \
# 0                NaN            0.576204              0.013197  ...
# 1                NaN            0.713204          -9999.000000  ...
# 2                NaN            0.767968          -9999.000000  ...
# 3                NaN            0.670307              0.021719  ...
# 4                NaN            0.008103          -9999.000000  ...
# ...              ...                 ...                   ...  ...
# 40017            NaN            0.775838              0.023715  ...
# 40018            NaN            0.002722              0.036059  ...
# 40019  -3.402823e+38            0.554224          -9999.000000  ...
# 40020            NaN            0.021926          -9999.000000  ...
# 40021            NaN            0.637037          -9999.000000  ...
#
#        tipl_distrib_v2016  ulgl_distrib_v2016  bepe_distrib_v2016  \
# 0                0.000827        5.844794e-06            0.697052
# 1                0.010973        7.097719e-04            0.546788
# 2                0.026102        8.237094e-04            0.336591
# 3                0.019704        4.144382e-04            0.236383
# 4                0.001383        5.346998e-08            0.000447
# ...                   ...                 ...                 ...
# 40017            0.020294        4.261766e-04            0.312127
# 40018            0.001820        9.983832e-04            0.151881
# 40019            0.029674        1.838178e-03            0.183773
# 40020            0.002897        2.257393e-03            0.284154
# 40021            0.024399        1.119324e-03            0.443494
#
#        fasy_if_v2018  piab_mortalite_v2018  prec_6190_et_v1  \
# 0       2.523884e+01          -9999.000000       149.581284
# 1       2.783585e+01          -9999.000000       204.346466
# 2       2.882230e+01          -9999.000000       184.735458
# 3       2.709109e+01          -9999.000000       138.204391
# 4      -3.402823e+38          -9999.000000       111.139496
# ...              ...                   ...              ...
# 40017   2.901571e+01          -9999.000000       173.473053
# 40018  -3.402823e+38          -9999.000000       216.782501
# 40019  -3.402823e+38          -9999.000000       199.467590
# 40020   2.129047e+01              0.007716       222.490387
# 40021   2.789792e+01          -9999.000000       199.358246
#
#        qupy_mortalite_v2018  saca_distrib_v2016  tm61858610_13  \
# 0                   -9999.0            0.231549       0.805501
# 1                   -9999.0            0.184128       1.065304
# 2                   -9999.0            0.167884       1.021843
# 3                   -9999.0            0.096158       0.913146
# 4                   -9999.0            0.004683       0.931766
# ...                     ...                 ...            ...
# 40017               -9999.0            0.183173       0.945098
# 40018               -9999.0            0.246417       0.843088
# 40019               -9999.0            0.109920       0.942872
# 40020               -9999.0            0.252481       0.986910
# 40021               -9999.0            0.179867       1.012201
#
#        ulmi_distrib_v2016
# 0                0.001437
# 1                0.012006
# 2                0.064354
# 3                0.035805
# 4                0.042788
# ...                   ...
# 40017            0.087864
# 40018            0.000300
# 40019            0.051256
# 40020            0.000227
# 40021            0.018302
#
# [40022 rows x 83 columns]

# %%
# Save it
df_slow_merged.to_feather("data_agroparistech_slowfiles_before_qc.feather")
df_slow_merged.to_csv("data_agroparistech_slowfiles_before_qc.csv", index=False)

# %% [markdown]
# ## Quality Control For Outliers / NA Values

# %%
# Merge slow and fast files into one

df_slow_files = pd.read_feather("data_agroparistech_slowfiles_before_qc.feather")
df_fast_files = pd.read_feather("data_agroparistech_fastfiles_before_qc.feather")

df_agroparistech = pd.merge(
    df_slow_files, df_fast_files, on=["idp", "y_fr", "x_fr"], how="right"
)

df_agroparistech.head()
# Out:
#       idp           x_fr          y_fr  bhctu_6190_an_v1  bhctu_6190_et_v1  \
# 0  632691  267415.027897  6.820144e+06         19.240328        -56.831585
# 1  702597  726971.216676  6.566524e+06          2.667820        -53.173649
# 2  706240  727562.508709  6.636462e+06          5.251337        -58.659328
# 3  708321  507027.573495  6.792198e+06         -0.896232        -65.469238
# 4  708369  981009.515199  6.248657e+06         -5.091545       -106.926773
#
#    etp_6190_an_v1  etp_6190_et_v1  rad_6190_an_v1  abal_distrib_v2016  \
# 0       54.696297      105.875206    34664.031250            0.116299
# 1       59.746429      121.191681    36479.175781            0.085622
# 2       59.844738      120.269440    35390.437500            0.051618
# 3       55.652546      111.108696    32837.777344            0.040013
# 4       77.560204      142.603653    45841.847656            0.000747
#
#    bepe_mortalite_v2018  ...  tipl_distrib_v2016  ulgl_distrib_v2016  \
# 0             -0.006745  ...            0.000827        5.844794e-06
# 1          -9999.000000  ...            0.010973        7.097719e-04
# 2          -9999.000000  ...            0.026102        8.237094e-04
# 3             -0.006780  ...            0.019704        4.144382e-04
# 4          -9999.000000  ...            0.001383        5.346998e-08
#
#    bepe_distrib_v2016  fasy_if_v2018  piab_mortalite_v2018  prec_6190_et_v1  \
# 0            0.697052   2.523884e+01               -9999.0       149.581284
# 1            0.546788   2.783585e+01               -9999.0       204.346466
# 2            0.336591   2.882230e+01               -9999.0       184.735458
# 3            0.236383   2.709109e+01               -9999.0       138.204391
# 4            0.000447  -3.402823e+38               -9999.0       111.139496
#
#    qupy_mortalite_v2018  saca_distrib_v2016  tm61858610_13  ulmi_distrib_v2016
# 0               -9999.0            0.231549       0.805501            0.001437
# 1               -9999.0            0.184128       1.065304            0.012006
# 2               -9999.0            0.167884       1.021843            0.064354
# 3               -9999.0            0.096158       0.913146            0.035805
# 4               -9999.0            0.004683       0.931766            0.042788
#
# [5 rows x 88 columns]
